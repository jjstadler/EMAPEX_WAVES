# %%
#Plot AVISO and NISKINE/SMILE/ARCTERX data on top of AVISO vorticity


from scipy.io import loadmat, savemat
from scipy import signal
from scipy.io import netcdf
import numpy as np
import time
import pyIGRF
import datetime
import pandas as pd
import matplotlib.pyplot as plt
#from wavesim1d import *
from src.em_apex_processing import *
from src.spectral_processing import *
import os
import warnings





import matplotlib.gridspec as gridspec

from matplotlib import cm, ticker

# %%
aviso_fname = "/Users/jamesstadler/Documents/UW/TFO/Data/NISKINE/aviso_stats_07-11.mat"
gf = loadmat(aviso_fname)

# %%
#m_pcolor(gf.slon,gf.slat,gf.vort_rms); shading flat
from matplotlib.colors import LogNorm

#plt.contourf(gf['slon'][0, :], gf['slat'][:, 0], gf['vort_rms'], locator=ticker.LogLocator(), cmap='RdBu_r')
plt.contourf(gf['slon'][0, :], gf['slat'][:, 0], gf['vort_rms'], levels=[5e-9, 1e-8, 5e-8, 1e-7, 5e-7, 7e-7, 1e-6, 3e-6, 5e-6, 7e-6, 8e-6, 9e-6, 1e-5, 1.5e-5, 1.8e-5, 2e-5, 2.2e-5, 2.5e-5], cmap='RdBu_r')

# %%
np.nanmin(gf['vort_rms'])
# Out:
# 3.6946347739021592e-09

# %%
vort = gf['vort_rms']

# %%
vort
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])
